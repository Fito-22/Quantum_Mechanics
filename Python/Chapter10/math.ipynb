# %%
import numpy as np
e = 1.602 * 10**-19
e0 = 8.85 * 10**-12
m = 9.11 * 10**-31
h = 1.05457 * 10**-34

# %%
B = e**3 * m**2*3 /(h**3 * 16 * np.pi**2 * e0**2 * 4)
print(B)
# Out:
# 176422.12366541682

# %%
E1=-2.1798723637575177e-18
E2=-5.449680909393794e-19
E3=-2.42208040417502e-19
B=1


EB_= E2-(e*B*h/(2*m))
EBplus = E2+(e*B*h/(2*m))

(E1-EBplus)/(h*2*np.pi), (E1-EB_)/(h*2*np.pi)
# Out:
# (-2467399719700960.5, -2467371732190660.5)

# %%
A=E1
Blow=2

c = e*Blow*h/(2*m*A)
c
# Out:
# -8.507236020817775e-06

# %%
n=45
m_2=-40
m_1=40

(2*n**2+ 2*n + 1 )/ (n**2 *(n+1)**2 *(m_2-m_1))
# Out:
# -1.2080211906928983e-05
