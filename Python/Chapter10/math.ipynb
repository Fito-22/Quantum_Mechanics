# %%
import numpy as np
e = 1.602 * 10**-19
e0 = 8.85 * 10**-12
m = 9.11 * 10**-31
h = 1.05457 * 10**-34

# %%
B = e**3 * m**2*3 /(h**3 * 16 * np.pi**2 * e0**2 * 4)
print(B)
# Out:
# 176422.12366541682
